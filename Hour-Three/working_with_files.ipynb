# %%
#Listing files

# %%
# !ls
# Out:
# Untitled.ipynb      Untitled1.ipynb     filename            script_basics.ipynb

# %%
# ls does not tell whether the listing is files or directory.
#To find which one is file and which one is directory use -F as follow

# %%
# !ls -F
# Out:
# Untitled.ipynb       filename*            script_basics.ipynb
# Untitled1.ipynb      folders/

# %%
# if there is / at the end then it is a direcotry as folders in above is directory.

# %%
# we can use -1 also as below to see in vertical as like below
# !ls -1
# Out:
# Untitled.ipynb
# Untitled1.ipynb
# filename
# folders
# script_basics.ipynb

# %%
# files and folder with . are hiddens
# To see the hidden files and folder do the following
# !ls -a
# Out:
# .                   .ipynb_checkpoints  Untitled1.ipynb     folders
# ..                  Untitled.ipynb      filename            script_basics.ipynb

# %%
# !ls -a -F
# Out:
# ./                   Untitled.ipynb       folders/
# ../                  Untitled1.ipynb      script_basics.ipynb
# .ipynb_checkpoints/  filename*

# %%
# The above command can be grouped together as below

# %%
# !ls -AF
# Out:
# .ipynb_checkpoints/  Untitled1.ipynb      folders/
# Untitled.ipynb       filename*            script_basics.ipynb

# %%
# !ls -aF1
# Out:
# ./
# ../
# .ipynb_checkpoints/
# Untitled.ipynb
# Untitled1.ipynb
# filename*
# folders/
# script_basics.ipynb

# %%
# !ls -1FA
# Out:
# .ipynb_checkpoints/
# Untitled.ipynb
# Untitled1.ipynb
# filename*
# folders/
# script_basics.ipynb

# %%
#changing the position of above grouped does not make the difference.

# %%
# To view the content of a file, use cat
# !cat Untitled.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 4,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# We should choose appropriate shell.\n",
#     "#To make any file executable, do the following "
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 13,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "Untitled.ipynb  filename\r\n"
#      ]
#     }
#    ],
#    "source": [
#     "ls\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 9,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# We have a file name as filename which is not executable\n",
#     "# we do the following to make it executable. \n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 14,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "!chmod a+x filename"
#    ]
#   },
#   {
#    "cell_type": "code",
# ...

# %%
# -n can be used to numbering the line such as

# %%
# !cat -n Untitled.ipynb
# Out:
#      1	{
#      2	 "cells": [
#      3	  {
#      4	   "cell_type": "code",
#      5	   "execution_count": 4,
#      6	   "metadata": {},
#      7	   "outputs": [],
#      8	   "source": [
#      9	    "# We should choose appropriate shell.\n",
#     10	    "#To make any file executable, do the following "
#     11	   ]
#     12	  },
#     13	  {
#     14	   "cell_type": "code",
#     15	   "execution_count": 13,
#     16	   "metadata": {},
#     17	   "outputs": [
#     18	    {
#     19	     "name": "stdout",
#     20	     "output_type": "stream",
#     21	     "text": [
#     22	      "Untitled.ipynb  filename\r\n"
#     23	     ]
#     24	    }
#     25	   ],
#     26	   "source": [
#     27	    "ls\n"
#     28	   ]
#     29	  },
#     30	  {
#     31	   "cell_type": "code",
#     32	   "execution_count": 9,
#     33	   "metadata": {},
#     34	   "outputs": [],
#     35	   "source": [
#     36	    "# We have a file name as filename which is not executable\n",
# ...

# %%
# !cat -b Untitled.ipynb
# Out:
#      1	{
#      2	 "cells": [
#      3	  {
#      4	   "cell_type": "code",
#      5	   "execution_count": 4,
#      6	   "metadata": {},
#      7	   "outputs": [],
#      8	   "source": [
#      9	    "# We should choose appropriate shell.\n",
#     10	    "#To make any file executable, do the following "
#     11	   ]
#     12	  },
#     13	  {
#     14	   "cell_type": "code",
#     15	   "execution_count": 13,
#     16	   "metadata": {},
#     17	   "outputs": [
#     18	    {
#     19	     "name": "stdout",
#     20	     "output_type": "stream",
#     21	     "text": [
#     22	      "Untitled.ipynb  filename\r\n"
#     23	     ]
#     24	    }
#     25	   ],
#     26	   "source": [
#     27	    "ls\n"
#     28	   ]
#     29	  },
#     30	  {
#     31	   "cell_type": "code",
#     32	   "execution_count": 9,
#     33	   "metadata": {},
#     34	   "outputs": [],
#     35	   "source": [
#     36	    "# We have a file name as filename which is not executable\n",
# ...

# %%
# To count the words in file use wc command as

# %%
# !wc Untitled.ipynb
# Out:
#      909    5199   46395 Untitled.ipynb

# %%
#first line 909 is total number of line in the file
#second line 5199 is total number of words 
#third line 46395 is total number of characters

# %%
#To just see line use -l, to see the word use -w and two counts the number of character use -m or -c

# %%
# !wc -l Untitled.ipynb
# Out:
#      909 Untitled.ipynb

# %%
# !wc -w Untitled.ipynb
# Out:
#     5199 Untitled.ipynb

# %%
# !wc -c Untitled.ipynb
# Out:
#    46395 Untitled.ipynb

# %%
# !wc -m Untitled.ipynb
# Out:
#    46395 Untitled.ipynb

# %%
#To copy use cp source destination syntax
# !cp filename file1

# %%
# !ls
# Out:
# Untitled.ipynb           filename                 working_with_files.ipynb
# Untitled1.ipynb          folders
# file1                    script_basics.ipynb

# %%
# If the destination file is already exists then to avoid overwritten use cp -i as follow:

# %%
# !cp -i filename file1

# %%
#To rename file use mv oldfile newfile

# %%
# !mv file1 file2
# Out:
# mv: file1: No such file or directory

# %%
# !ls
# Out:
# Untitled.ipynb           filename                 working_with_files.ipynb
# Untitled1.ipynb          folders
# file2                    script_basics.ipynb

# %%
#interactive mode use mv -i soruce destination
# !mv -i file2 file1

# %%
# !ls
# Out:
# Untitled.ipynb           filename                 working_with_files.ipynb
# Untitled1.ipynb          folders
# file1                    script_basics.ipynb

# %% [raw]
# # Remove file use rm

# %%
# !rm file1

# %%
# !ls
# Out:
# Untitled.ipynb           filename                 script_basics.ipynb
# Untitled1.ipynb          folders                  working_with_files.ipynb

# %%
# !cp filename file2

# %%
# !ls
# Out:
# Untitled.ipynb           filename                 working_with_files.ipynb
# Untitled1.ipynb          folders
# file2                    script_basics.ipynb

# %%
# !rm -i file2
# Out:
# remove file2?
